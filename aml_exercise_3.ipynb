# %% [markdown]
# <a href="https://colab.research.google.com/github/KunderLavanya/APS_LAB/blob/main/aml_exercise_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
x=np.array([78, 85, 92, 67, 88])
p=pd.Series(x)
print(p)
#values
print(p.values)
print(p.index.tolist())
print(p.dtype)
print(p.mean())
print(p.max())
print(p.min())
# Out:
# 0    78
# 1    85
# 2    92
# 3    67
# 4    88
# dtype: int64
# [78 85 92 67 88]
# [0, 1, 2, 3, 4]
# int64
# 82.0
# 92
# 67

# %%
dictt={'student': ['asha','ravi','meena','kiran','arun'],
       'Marks': [85,78,92,74,88]
       }
d=pd.DataFrame(dictt)
print(d)
#Display the marks of Meena.
print(d['Marks'])
print()
# Out:
#   student  Marks
# 0    asha     85
# 1    ravi     78
# 2   meena     92
# 3   kiran     74
# 4    arun     88
# 0    85
# 1    78
# 2    92
# 3    74
# 4    88
# Name: Marks, dtype: int64
